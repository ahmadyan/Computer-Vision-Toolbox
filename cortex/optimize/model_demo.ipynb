# %%
# Import usual suspects
import numpy as np
import sys
sys.path.append("../")

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
import mpl_toolkits.mplot3d.axes3d as p3
from matplotlib.colors import LogNorm
from itertools import zip_longest
from IPython.display import HTML, display
from visualization.animation import TrajectoryAnimation, TrajectoryAnimation3D
from visualization.render import plot_contour, plot_3d_surface

# create the grid
num = 100
range = [-1, 1, -1, 1]
w1, w2 = np.meshgrid(np.linspace(range[0], range[1], num=num), np.linspace(range[2], range[3], num=num))

# %% [markdown]
# # Ed's spiral function

# %%
from model_zoo import rosten

z = rosten(w1.flatten(), w2.flatten())
z = np.reshape(z, (num, num));
_ = plot_3d_surface(w1, w2, z, range[0], range[1])
_ = plot_contour(w1, w2, z, range[2], range[3])
